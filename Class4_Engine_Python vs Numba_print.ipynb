# %% [markdown]
# ![2024-02-22%2020_16_15-DADS5001_Class4_20240203.MOV.png](attachment:2024-02-22%2020_16_15-DADS5001_Class4_20240203.MOV.png)

# %%
import pandas as pd
import numpy as np

# Set seed for reproducibility
np.random.seed(42)

# Generate a DataFrame with 1,000,000 rows and 10 columns
data = np.random.randint(1, 11, size=(1000000, 10))

# Create a DataFrame
df = pd.DataFrame(data, columns=[f'col_{i}' for i in range(1, 11)])

# Apply square root to each cell using the default Python engine
df = df.apply(np.sqrt)

# Display the DataFrame
df
# Out:
#            col_1     col_2     col_3     col_4     col_5     col_6     col_7  \
# 0       2.645751  2.000000  2.828427  2.236068  2.645751  3.162278  1.732051
# 1       2.000000  2.828427  2.828427  1.732051  2.449490  2.236068  1.414214
# 2       2.236068  1.000000  3.162278  2.449490  3.000000  1.000000  3.162278
# 3       3.000000  1.732051  2.236068  1.732051  2.645751  2.236068  3.000000
# 4       3.000000  1.414214  3.162278  3.000000  3.162278  2.236068  1.414214
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  2.236068  3.162278  1.414214  2.000000  2.645751  1.414214  2.236068
# 999996  3.162278  3.162278  1.000000  2.645751  2.645751  1.000000  2.000000
# 999997  1.414214  3.000000  2.236068  3.000000  3.000000  3.162278  3.000000
# 999998  1.000000  1.732051  3.162278  2.236068  2.828427  1.732051  2.645751
# 999999  2.000000  1.000000  3.000000  2.828427  2.645751  2.236068  3.162278
#
#            col_8     col_9    col_10
# 0       2.645751  2.828427  2.236068
# 1       2.828427  2.449490  1.414214
# 2       1.732051  2.645751  2.000000
# 3       2.645751  1.414214  2.000000
# 4       2.000000  2.645751  2.828427
# ...          ...       ...       ...
# 999995  1.414214  1.732051  2.449490
# 999996  2.449490  2.645751  1.414214
# 999997  1.732051  1.414214  2.645751
# 999998  2.645751  1.000000  2.645751
# 999999  2.236068  1.000000  1.414214
#
# [1000000 rows x 10 columns]

# %%
# %%timeit

import pandas as pd
import numpy as np

# Set seed for reproducibility
np.random.seed(42)

# Generate a DataFrame with 1,000,000 rows and 10 columns
data = np.random.randint(1, 11, size=(1000000, 10))

# Create a DataFrame
df = pd.DataFrame(data, columns=[f'col_{i}' for i in range(1, 11)])

# Apply square root to each cell using the default Python engine
df = df.apply(np.sqrt)

# Display the DataFrame
df
# Out:
# 161 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Numba

# %%
pip install numba
# Out:
# Requirement already satisfied: numba in c:\users\nattachai jairak\anaconda3\lib\site-packages (0.57.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from numba) (0.40.0)
# Requirement already satisfied: numpy<1.25,>=1.21 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from numba) (1.24.3)

# %%
import pandas as pd
import numpy as np
from numba import njit

# Set seed for reproducibility
np.random.seed(42)

# Generate a DataFrame with 1,000,000 rows and 10 columns
data = np.random.randint(1, 11, size=(1000000, 10))

# Create a DataFrame
df = pd.DataFrame(data, columns=[f'col_{i}' for i in range(1, 11)])

# Numba JIT decorator for the square root function
@njit
def sqrt_numba(x):
    return np.sqrt(x)

# Apply square root to each cell using the Numba engine
df = df.apply(np.vectorize(sqrt_numba))

# Display the DataFrame
df
# Out:
#            col_1     col_2     col_3     col_4     col_5     col_6     col_7  \
# 0       2.645751  2.000000  2.828427  2.236068  2.645751  3.162278  1.732051
# 1       2.000000  2.828427  2.828427  1.732051  2.449490  2.236068  1.414214
# 2       2.236068  1.000000  3.162278  2.449490  3.000000  1.000000  3.162278
# 3       3.000000  1.732051  2.236068  1.732051  2.645751  2.236068  3.000000
# 4       3.000000  1.414214  3.162278  3.000000  3.162278  2.236068  1.414214
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  2.236068  3.162278  1.414214  2.000000  2.645751  1.414214  2.236068
# 999996  3.162278  3.162278  1.000000  2.645751  2.645751  1.000000  2.000000
# 999997  1.414214  3.000000  2.236068  3.000000  3.000000  3.162278  3.000000
# 999998  1.000000  1.732051  3.162278  2.236068  2.828427  1.732051  2.645751
# 999999  2.000000  1.000000  3.000000  2.828427  2.645751  2.236068  3.162278
#
#            col_8     col_9    col_10
# 0       2.645751  2.828427  2.236068
# 1       2.828427  2.449490  1.414214
# 2       1.732051  2.645751  2.000000
# 3       2.645751  1.414214  2.000000
# 4       2.000000  2.645751  2.828427
# ...          ...       ...       ...
# 999995  1.414214  1.732051  2.449490
# 999996  2.449490  2.645751  1.414214
# 999997  1.732051  1.414214  2.645751
# 999998  2.645751  1.000000  2.645751
# 999999  2.236068  1.000000  1.414214
#
# [1000000 rows x 10 columns]

# %%
# %%timeit

import pandas as pd
import numpy as np
from numba import njit

# Set seed for reproducibility
np.random.seed(42)

# Generate a DataFrame with 1,000,000 rows and 10 columns
data = np.random.randint(1, 11, size=(1000000, 10))

# Create a DataFrame
df = pd.DataFrame(data, columns=[f'col_{i}' for i in range(1, 11)])

# Numba JIT decorator for the square root function
@njit
def sqrt_numba(x):
    return np.sqrt(x)

# Apply square root to each cell using the Numba engine
df = df.apply(np.vectorize(sqrt_numba))

# Display the DataFrame
df
# Out:
# 1.99 s ± 36.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nattachai jairak\anaconda3\lib\site-packages (3.7.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nattachai jairak\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# Time results in seconds
python_time = 161 / 1000  # Convert milliseconds to seconds
numba_time = 1.99 / 1000  # Convert milliseconds to seconds

# Data for the bar chart
labels = ['Python', 'Numba']
times = [python_time, numba_time]

# Plotting the bar chart
plt.bar(labels, times, color=['blue', 'orange'])
plt.ylabel('Time (seconds)')
plt.title('Computing Time Comparison between Numba and Python')
plt.show()
